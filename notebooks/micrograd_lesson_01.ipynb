# %% [markdown]
# # Micrograd Lesson 01
#
# Notes and experiments while following Andrej Karpathy's micrograd course.

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
# A tiny scalar example to start thinking about derivatives.
def f(x):
    return 3 * x**2 - 4 * x + 5

xs = np.arange(-5, 5, 0.25)
ys = f(xs)
plt.plot(xs, ys);
